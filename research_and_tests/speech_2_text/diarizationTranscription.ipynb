# %%
import torch
from faster_whisper import WhisperModel
from pyannote.audio import Pipeline
import numpy as np
import librosa
import soundfile as sf

audioPath = "C:/Users/Jose/Desktop/Hackathon/Speech2Text/"
audioName = 'convPepeTrijoMaggi.wav' ## Filtered audio file
model_size = "medium"

# %%
tokenFile = "HuggingFaceToken.txt"
file1 = open(audioPath + tokenFile, 'r')
token = file1.readline()

# %% [markdown]
# First, using the pipeline of pyannote create the diarization of the speakers with the begining and end times of their frases

# %%
model = WhisperModel(model_size, device="cpu", compute_type="int8")

pipeline = Pipeline.from_pretrained(
    "pyannote/speaker-diarization-3.1",
    use_auth_token=token)

audio_file = audioPath + audioName

diarization = pipeline({'uri': 'filename', 'audio': audio_file})

segments = []
for turn, _, speaker in diarization.itertracks(yield_label=True):
    segments.append({
        'start': turn.start,
        'end': turn.end,
        'speaker': speaker
    })

# %% [markdown]
# Then, process each segment using a temp wav file for whisper to use. Some times whisper is not able to recognize anything on the recording so there is a try-except to add some text for the code to continue running.
# By not fixing the language the model performs better and faster (for one segment forcing spanish it takes like 10 times more)

# %%
def transcribe_segment(start, end, audio_path):
    y, sr = librosa.load(audio_path, sr=None, offset=start, duration=(end - start))
    sf.write("temp_segment.wav", y, sr)
    segments, info = model.transcribe("temp_segment.wav")
    counter = 0
    for segment in segments:
        counter += 1
        continue
        #print("[%.2fs -> %.2fs] %s" % (segment.start, segment.end, segment.text))
    print(str(counter) + " Segments")
    try:
        return segment.text
    except:
        return "Unidentified"

# %% [markdown]
# Finally transcribe the complete audio and save the transcription to a txt file

# %%
# Transcribe each segment and print
output_txt_path = 'transcription.txt'
with open(output_txt_path, 'w') as f:
    f.write("Transcription:\n")
    for segment in segments:
        text = transcribe_segment(segment['start'], segment['end'], audio_file)
        print(f"{segment['speaker']} [{round(segment['start'], 2)} - {round(segment['end'], 2)}]: {text}")
        try:
            f.write(f"{segment['speaker']} [{round(segment['start'], 2)} - {round(segment['end'], 2)}]: {text} \n")
        except:
            f.write("Unidentified \n")
# Out:
# 1 Segments
# SPEAKER_01 [1.47 - 1.99]: 稍等一下
# 1 Segments
# SPEAKER_01 [3.27 - 8.65]:  Les quería preguntar cómo les fue el día que llevó la cagada con la tormenta.
# 1 Segments
# SPEAKER_00 [16.83 - 18.31]:  Ya, yuktu!
# 1 Segments
# SPEAKER_00 [19.04 - 20.72]:  Hasta el miércoles sin luz.
# 1 Segments
# SPEAKER_00 [21.59 - 24.71]:  y venía a Karlaúa a pensar energía.
# 1 Segments
# SPEAKER_02 [32.08 - 39.19]:  Yo al contrario, tuve el gusto rato, no se me cortó menos mal, pero mis hermanos vinieron hasta mis primas.
# 1 Segments
# SPEAKER_02 [39.57 - 40.67]: しめろなー
# 1 Segments
# SPEAKER_02 [40.81 - 45.85]:  a pedirnos lujo, estamos cargando los celulares de todos, literalmente de todos, de los amigos.
# 1 Segments
# SPEAKER_00 [46.09 - 48.74]:  De amigo, de amigo, de mamá de amigo, e todo.
# 1 Segments
# SPEAKER_02 [46.09 - 48.96]:  de amigo, de mamá de amigo, e tos.
# 1 Segments
# SPEAKER_02 [49.3 - 53.57]:  La cuenta de luz, no sé cómo salió, pero fue muy chistoso para estar por cada...
# 1 Segments
# SPEAKER_00 [50.18 - 50.74]:  ¿Cómo salió?
# 1 Segments
# SPEAKER_02 [54.42 - 56.39]:  la interrupción.
# 1 Segments
# SPEAKER_02 [57.04 - 57.8]:  Enchufa, não é?
# 1 Segments
# SPEAKER_02 [58.38 - 61.83]:  Enchufa nuevo, celular nuevo que encontrado, es impresionante.
# 1 Segments
# SPEAKER_01 [66.8 - 68.99]:  Por mí fue terrible porque, de hecho...
# 1 Segments
# SPEAKER_01 [69.91 - 71.83]:  como mi entrada de la casa se inunda.
# 0 Segments
# SPEAKER_01 [72.5 - 73.29]: Unidentified
# 1 Segments
# SPEAKER_01 [73.79 - 75.98]:  Y nosotros sacamos el agua con una bomba eléctrica.
# 1 Segments
# SPEAKER_01 [76.68 - 78.26]:  Entonces, claro...
# 1 Segments
# SPEAKER_00 [77.82 - 78.06]:  Oh
# 1 Segments
# SPEAKER_01 [78.5 - 80.43]:  Pasó toda la noche sin luz.
# 0 Segments
# SPEAKER_00 [79.99 - 80.08]: Unidentified
# 1 Segments
# SPEAKER_01 [80.67 - 85.27]:  y el agua se empezó a juntar y no se estaba como subiendo el nivel del agua a punto de entrar a la casa
# 0 Segments
# SPEAKER_00 [81.54 - 81.96]: Unidentified
# 1 Segments
# SPEAKER_01 [85.76 - 87.21]:  Estamos como todos desesperados.
# 1 Segments
# SPEAKER_01 [88.24 - 89.89]:  Y después que en el tiempo...
# 1 Segments
# SPEAKER_01 [90.33 - 93.4]:  Decidimos ya activar una bomba de benzina que teníamos.
# 1 Segments
# SPEAKER_01 [93.69 - 94.92]:  Y la bomba no quería partir.
# 1 Segments
# SPEAKER_01 [95.39 - 101.01]:  y fue terrible, estuvimos medio siglo desarmando la bomba, como viendo la fujía del motor
# 1 Segments
# SPEAKER_01 [101.52 - 103.76]:  a ver si podíamos hacerla funcionar
# 1 Segments
# SPEAKER_01 [105.27 - 107.09]:  Hace un tiempo que ha chequeado...
# 1 Segments
# SPEAKER_01 [107.67 - 110.74]:  Como el ladeando y agitando la bomba, como hacia los lados.
# 1 Segments
# SPEAKER_01 [111.54 - 113.56]:  En lograr hacer la partitura porque...
# 1 Segments
# SPEAKER_01 [113.64 - 115.34]:  Probablemente la bujía está como...
# 1 Segments
# SPEAKER_01 [115.85 - 117.44]:  abogada en Bencina.
# 0 Segments
# SPEAKER_01 [117.97 - 118.38]: Unidentified
# 3 Segments
# SPEAKER_02 [145.07 - 152.62]:  No, no... ¿En cuál enlantrá que se...?
# 2 Segments
# SPEAKER_00 [145.61 - 149.09]:  en tu...
# 1 Segments
# SPEAKER_02 [153.27 - 154.47]:  que se inunda.
# 1 Segments
# SPEAKER_01 [158.11 - 163.2]:  Es la entrada principal de la casa, y mi pieza está justo al frente de la entrada principal de la casa.
# 1 Segments
# SPEAKER_01 [163.42 - 168.28]:  Entonces cuando se entra el agua, el agua como que sigue el camino hacia adelante y llega hasta mi pieza.
# 1 Segments
# SPEAKER_00 [166.78 - 167.26]:  Here you go.
# 1 Segments
# SPEAKER_01 [168.75 - 172.56]:  Y cuando lo inundamos, yo pongo los pies abajo de mi cama y escucho el avión, así como...
# 0 Segments
# SPEAKER_01 [172.88 - 172.95]: Unidentified
# 0 Segments
# SPEAKER_01 [172.98 - 173.0]: Unidentified
# 1 Segments
# SPEAKER_01 [177.73 - 180.98]:  Pero al final, lograron prender la bomba de...
# 0 Segments
# SPEAKER_00 [179.16 - 179.36]: Unidentified
# 1 Segments
# SPEAKER_00 [181.3 - 184.0]:  Esta encina funcionó y sacaron el agua.
# 0 Segments
# SPEAKER_01 [184.0 - 184.13]: Unidentified
# 1 Segments
# SPEAKER_01 [191.35 - 195.46]:  Sí, pues sí, como te decía, se agitaba la movida a su lado y...
# 1 Segments
# SPEAKER_01 [196.34 - 197.0]:  Wie funktioniert das?
# 1 Segments
# SPEAKER_01 [197.44 - 198.8]:  como Mitchell London.
# 1 Segments
# SPEAKER_00 [199.11 - 199.79]:  You
# 1 Segments
# SPEAKER_01 [199.82 - 208.65]:  Y es bacán, la bomba, como a vecina, traga agua como locas, el diámetro de la manguera es gigante y el agua adelante va a salir en dos segundos.
# 1 Segments
# SPEAKER_01 [209.53 - 211.72]:  pero antes de eso lo pasaba un pesimulo.
# 0 Segments
# SPEAKER_00 [214.39 - 214.68]: Unidentified
# 1 Segments
# SPEAKER_01 [214.68 - 220.01]:  ¿Qué tal los muebles? Quiero muy por la cagada, todas las patas hinchas, ¿sabes?
# 1 Segments
# SPEAKER_00 [216.88 - 217.5]:  I didn't...
# 1 Segments
# SPEAKER_01 [222.89 - 224.86]:  A ver, no hay caso de bajar, pero...
# 1 Segments
# SPEAKER_01 [225.2 - 226.19]:  Ehm...
# 1 Segments
# SPEAKER_01 [226.48 - 228.68]:  Cuando una vez que se nos entró el agua...
# 1 Segments
# SPEAKER_01 [229.18 - 229.57]:  OK.
# 1 Segments
# SPEAKER_01 [229.96 - 232.16]:  Como que todo el suelo de piso flotante que hubo...
# 1 Segments
# SPEAKER_01 [232.5 - 234.61]:  Húmedo abajo, tenemos como humedad.
# 0 Segments
# SPEAKER_00 [232.57 - 232.66]: Unidentified
# 0 Segments
# SPEAKER_00 [232.81 - 232.93]: Unidentified
# 1 Segments
# SPEAKER_01 [234.71 - 237.38]:  Hasta el día de hoy bajo el suelo que tejamos todos los días.
# 1 Segments
# SPEAKER_01 [242.98 - 243.52]:  Bye-bye.
